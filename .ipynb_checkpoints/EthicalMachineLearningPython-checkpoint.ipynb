# %% [markdown]
# # Ethical Machine Learning
#
# ## _Spotting and Preventing Proxy Bias_
#
# #### Paige Bailey - 22 April 2018 (Editted For Python by Eric Schles)
#
# -------------------
#
# Machine learning systems often inherit biases against protected classes and historically disparaged groups via their training data [1](https://arxiv.org/pdf/1707.08120.pdf). Though some biases in features are straightforward to detect (ex: age, gender, race), others are not explicit and rely on subtle correlations in machine learning algorithms to detect. The incorporation of unintended bias into predictive models is called _proxy discrimination_.
#
# ---------------------
#
# _Example of proxy bias in a bank's loan decision workflow._
#
# ![](ethical_bias.JPG)
#
# ---------------------
#
# In this exercise, we will be implementing an example machine learning problem using decision trees, and determining whether its classification for loan recipients is biased against certain groups. We will explore several ways of detecting unintentional bias and removing it from our predictive model.
#
# **Please note**: the techniques used in this exercise only support _linear models_, _decision trees_, _rule lists_, and _random forests_ - not deep learning models or neural networks. However, the supported models represent a significant fraction of models used in practice in predictive systems that operate on personal information, ranging from advertising [2](http://www.bing.com), psychopathy [3](http://www.bing.com), criminal justice [4](http://www.bing.com), [5](http://www.bing.com), and actuarial sciences [6](http://www.bing.com), [7](http://www.bing.com).
#
#
# -------------------
#
#
# ## Step 0: Install and Load Required Packages

# %%
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
from sklearn import linear_model
# %matplotlib inline

# %% [markdown]
# ### Define the purpose and goal of your machine learning product.
#
# As you design the goal and the purpose of your machine learning product, you must first ask: **Who is your audience**?
#
# * Is your product or analysis meant to include all people?
# * And, if not: is it targeted to an exclusive audience?
# * Is there a person on your team tasked specifically with identifying and resolving bias and discrimination issues?
#
# Our audience for this product will be managers at a bank who are tasked with making decisions on who should be given loans - decidedly **not** a public audience. As data the data scientist assigned to this project, we can assume that we are responsible for resolving all bias and discrimination issues.
#
# ------------------------------------------
#
# ### Scope
#
# After you have defined the concept of your machine learning problem, you need to **identify possible outcomes and define criteria that contribute to them**.
#
# * How transparent will you be about the relationships between the inputs and the anticipated outcomes?
# * Are there sensitive characteristics you need to monitor in your data in order to observe their effect on your outputs?
#
# We will be extremely transparent with the managers, and likely less so with the bank's customers. Much of the data we will be dealing with is sensitive and personal - ages, addresses, credit histories, names, income.
#
# * Could your expectations rely on unacknowledged bias of you and your team?
#
# Absolutely - that is something that we are hoping to combat by examing any potential proxy bias. A way to check whether this analysis makes sense will be to ask a **diverse audience** if the expectations align with what is expected.
#
# -------------------------------------------
#
#
# ### Data
#
# Once the concept and scope have been defined, it is time to focus on the acquisition, evaluation, and cleaning of data. We have received a single .csv file filled with information on customers from the bank's manager. Some questions to consider:
#
# * Did the data come from a system prone to human error?
# * Is the data current?
# * What technology facilitated the collection of the data?
# * Was participation of the data subjects voluntary?
# * Does the context of the collection match the context of your use?
# * Was your data collected by people or a system that was operating with quotas or a particular incentive structure?
#
# To the best of our knowledge, the data does not come from a system prone to human error, is current, and has been accepted as valid by our customer, the bank's manager. We do not know what technology facilitated the data collection, and we can assume that the data was submitted voluntary by potential loan awardees (the context of our use).
#
# --------------------------------------------------
#
# Now that your data has been collected, it would be a great idea to evaluate and describe it:
#
# * Who is represented in the data?
# * Who is under-represented or absent from your data?
# * Can you find additional data, or use statistical methods, to make your data more inclusive?
# * Was the data collected in an environment where data subjects had meaningful choices?
# * How does the data reflect the perspective of the institution that collected it?
# * Were fields within the data inferred or appended beyond what was clear to the data subject?
# * Would this use of the data surprise the data subjects?
#
# The next step would be cleaning the data.
#
# * Are there any fields that should be eliminated from your data?
# * Can you use anonymization or pseudonymization techniques to avoid needless evaluation or processing of individual data?
#
# Several known fields of bias (`gender`, `age`, and `race`) will need to be removed from the data set. Thankfully, the .csv file has already been anonymized; names, specific birth dates, and exact addresses have been removed.
#
# ----------------------------
#
#
# ## Step 1: Import data
#
# The following is a synthetic data set, based heavily on the 1000-sample, open-source [German credit agency data set](http://archive.ics.uci.edu/ml/) hosted by UC Irvine. Four features were added: **zip code**, **race**, **gender**, and **status**. Racial and gender demographics by zip code are taken from 2010 United States Census data.
#
# You can see that the factors in our .csv are a mix of numeric and categorical features.

# %%
credit = pd.read_csv("loans.csv")
credit.head()
# Out:
#     age  amount checking_balance credit_history default  dependents  \
# 0  26.0  8845.0          < 0 USD      excellent     yes         2.0
# 1  25.0   178.0          unknown      excellent     yes         3.0
# 2  33.0   208.0          unknown      no credit     yes         2.0
# 3  78.0  6693.0          < 0 USD           good      no         1.0
# 4  23.0  3621.0          < 0 USD       critical     yes         3.0
#
#   employment_duration  existing_loans_count gender housing   ...     \
# 0             unknown                   3.0      M     own   ...
# 1             unknown                   0.0      M   other   ...
# 2         3 - 5 years                   1.0      F    rent   ...
# 3            < 1 year                   1.0      M   other   ...
# 4           > 7 years                   1.0      M    rent   ...
#
#   months_loan_duration  other_credit percent_of_income  phone    purpose race  \
# 0                 33.0          bank               1.0     no  education   SA
# 1                 52.0        stores               8.0    yes  education   AA
# 2                 19.0        stores              15.0    yes        car   BA
# 3                 57.0          none               6.0     no        car   SA
# 4                 20.0          bank               6.0    yes   business   AA
#
#   savings_balance    status years_at_residence  zipcode
# 0  500 - 1000 USD  divorced                1.0      604
# 1         unknown  divorced                2.0      603
# 2  500 - 1000 USD  divorced                9.0      611
# 3         unknown    single                1.0      603
# 4       < 100 USD    single               15.0      610
#
# [5 rows x 21 columns]

# %%
# Change zip to a factor rather than a numeric value.
credit['zipcode'] = credit['zipcode'].astype(str)

# %% [markdown]
# ### Constraining the data
#
# #### Establishing logic for variables
#
# * Can you describe the logic that connects the variables to the output of your equation?
# * Do your variables have a causal relationship to the results they predict?
# * How did you determine what weight to give each variable?
#
# #### Identifying assumptions
#
# * Will your variables apply equally across race, gender, age, disability, ethnicity, socioeconomic status, education, etc.?
# * What are you assuming about the kinds of people in your data set?
# * Would you be comfortable explaining your assumptions to the public?
# * What assumptions are you relying on to determine the relevant variables and their weights?
#
# #### Defining success
#
# * What amount and type of error do you expect?
# * How will you ensure your system is behaving the way you intend? How reliable is it?

# %% [markdown]
# Let's take a closer look at the checking and savings account balances, as well as racial demographics.

# %%
savings_race = credit.groupby(["savings_balance", "race"])["savings_balance"].count().unstack("race").fillna(0)
savings_race.plot(kind="bar", stacked=True, title="Savings Balance")
plt.show()

# %%
savings_gender = credit.groupby(["savings_balance", "gender"])["savings_balance"].count().unstack("gender").fillna(0)
savings_gender.plot(kind="bar", stacked=True, title="Savings Balance")
plt.show()

# %% [markdown]
# We can also take a closer look at percentages of savings account balances by race.

# %%
credit.groupby(["savings_balance", "race"]).size() / 10
# Out:
# savings_balance  race
# 100 - 500 USD    AA      5.6
#                  BA      4.4
#                  CA      5.3
#                  SA      5.4
# 500 - 1000 USD   AA      4.6
#                  BA      4.6
#                  CA      5.1
#                  SA      5.6
# < 100 USD        AA      5.8
#                  BA      5.5
#                  CA      4.9
#                  SA      4.1
# >1000 USD        AA      4.2
#                  BA      4.4
#                  CA      4.6
#                  SA      6.6
# unknown          AA      5.4
#                  BA      4.6
#                  CA      5.0
#                  SA      4.3
# dtype: float64

# %% [markdown]
# Though ideally our model would apply equally regardless of socioeconomic status, our customer (the bank's executives) have argued that there is a business need to include this feature. Checking account and savings account balances will both be incorporated into our final model.

# %%
checking_race = credit.groupby(["checking_balance", "race"])["checking_balance"].count().unstack("race").fillna(0)
checking_race.plot(kind="bar", stacked=True, title="Checking Balance")
plt.show()

# %%
checking_gender = credit.groupby(["checking_balance", "gender"])["checking_balance"].count().unstack("gender").fillna(0)
checking_gender.plot(kind="bar", stacked=True, title="Checking Balance")
plt.show()

# %%
credit.groupby(["checking_balance", "race"]).size() / 10
# Out:
# checking_balance  race
# 1 - 200 USD       AA      6.4
#                   BA      5.4
#                   CA      7.2
#                   SA      7.6
# < 0 USD           AA      6.4
#                   BA      5.7
#                   CA      5.5
#                   SA      5.6
# >= 200 USD        AA      6.0
#                   BA      5.9
#                   CA      6.2
#                   SA      6.8
# unknown           AA      6.8
#                   BA      6.5
#                   CA      6.0
#                   SA      6.0
# dtype: float64

# %% [markdown]
# As you can see in the histogram below, the majority of our data set is Caucasian (**CA**) at 44.2%, closely followed by African American (**AA**) at 35.8%, and then Asian American (**AS**) at 13.6% and Hispanic or Mixed Race (**MR**) at 6.4%.

# %%
credit.groupby(["race", "default"]).size() / 10
# Out:
# race  default
# AA    no         12.2
#       yes        13.4
# BA    no         11.8
#       yes        11.7
# CA    no         10.9
#       yes        14.0
# SA    no         11.8
#       yes        14.2
# dtype: float64

# %%
race_default = credit.groupby(["default", "race"])["default"].count().unstack("race").fillna(0)
race_default.plot(kind="bar", stacked=True, title="Default Status By Race")
plt.show()

# %% [markdown]
# When we break out the racial demographics by zip code, however, we see that it is obvious that race and address are linked. The 77005 and 77030 zip codes, located around West University and the Museum District, are predominantly Caucasian, while the 77021 and 77004 zip codes, in midtown and the __th__ ward, are predominantly African American.

# %%
zipcode_race = credit.groupby(["zipcode", "race"])["zipcode"].count().unstack("race").fillna(0)
zipcode_race.plot(kind="bar", stacked=True, title="Racial Demographics by Zip Code")
plt.show()

# %% [markdown]
# ![](htxzips.JPG)

# %%
credit["amount"].describe()
# Out:
# count    1000.000000
# mean     4900.456000
# std      2944.509393
# min        11.000000
# 25%      2234.000000
# 50%      4909.500000
# 75%      7464.000000
# max      9987.000000
# Name: amount, dtype: float64

# %%
credit["amount"].head()
# Out:
# [1] 1169 7882 6948 1934 1237 1585

# %% [markdown]
# #### Dividing into training and testing data sets
#
# Looks good to me! The first six values of `credit` and `credit_rand` are different, but the summary statistics look exactly the same. Now that we have a randomized data set, it's time to divide it into testing and training groups. Let's select 80% for training, and 20% for testing.
#
# For production machine learning proejcts, you would want to use a technique like **cross-validation**, and likely a 70/15/15 split for training/testing/validation.

# %%
credit_train <- credit_rand[1:800, ]
credit_test  <- credit_rand[801:1000, ]

# %% [markdown]
# To ensure that the training and testing data sets are representative of the full data set, you can check to make sure that there are ~30% loan defaults in each.

# %%
prop.table(table(credit_train$default))
# Out:
#      no     yes
# 0.69375 0.30625

# %%
prop.table(table(credit_test$default))
# Out:
#    no   yes
# 0.725 0.275

# %% [markdown]
# Close enough! Now let's remove the columns that we know are problematic (`race`, `gender`, `age`) and move on to training the model.

# %%
biased <- c('race', 'age', 'gender')

credit_train_new <- credit_train[ , !(names(credit_train) %in% biased)]
credit_test_new <- credit_test[, !(names(credit_test) %in% biased)]

# %% [markdown]
# --------------------------------------
#
# ## Step 3: Train a Model on the Data
#
# We will use the 17th column of our data set, `default`, as the variable that we will be attempting to predict. Once the model has been created using the single line of code below, we can inspect it by calling it and by using the `summary()` function.

# %%
credit_model <- C5.0(credit_train_new[-16], 
                     credit_train_new$default)

credit_model
# Out:
# Call:
# C5.0.default(x = credit_train_new[-16], y = credit_train_new$default)
#
# Classification Tree
# Number of samples: 800
# Number of predictors: 17
#
# Tree size: 51
#
# Non-standard options: attempt to group attributes

# %%
summary(credit_model)
# Out:
# Call:
# C5.0.default(x = credit_train_new[-16], y = credit_train_new$default)
#
#
# C5.0 [Release 2.07 GPL Edition]  	Fri May 25 06:51:57 2018
# -------------------------------
#
# Class specified by attribute `outcome'
#
# Read 800 cases (18 attributes) from undefined.data
#
# Decision tree:
#
# zip in {77005,77030}: no (317)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (47)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...credit_history in {perfect,very good}:
#         :...other_credit = none: yes (31/3)
#         :   other_credit in {bank,store}:
#         :   :...status = single: yes (7/1)
#         :       status = wife:
#         :       :...housing in {other,rent}: yes (2)
#         :       :   housing = own: no (7)
#         :       status = husband:
#         :       :...job = skilled: no (6/2)
#         :           job in {unemployed,unskilled}: yes (3)
#         :           job = management:
#         :           :...employment_duration in {< 1 year,1 - 4 years,
#         :               :                       4 - 7 years,
#         :               :                       unemployed}: no (2)
#         :               employment_duration = > 7 years: yes (2)
#         credit_history in {critical,good,poor}:
#         :...months_loan_duration > 22:
#             :...savings_balance = > 1000 USD: no (2/1)
#             :   savings_balance = 500 - 1000 USD: yes (3/1)
#             :   savings_balance = 100 - 500 USD:
#             :   :...employment_duration in {> 7 years,4 - 7 years,
#             :   :   :                       unemployed}: no (12/2)
#             :   :   employment_duration = 1 - 4 years: yes (5)
#             :   :   employment_duration = < 1 year:
#             :   :   :...status in {husband,single}: yes (6/1)
#             :   :       status = wife: no (1)
#             :   savings_balance = unknown:
#             :   :...checking_balance = 1 - 200 USD: no (14)
#             :   :   checking_balance = < 0 USD:
#             :   :   :...phone = no: yes (8/1)
#             :   :       phone = yes: no (4/1)
#             :   savings_balance = < 100 USD:
#             :   :...months_loan_duration > 47: yes (19/2)
#             :       months_loan_duration <= 47:
#             :       :...percent_of_income <= 3:
#             :           :...zip = 77054:
#             :           :   :...housing in {other,own}: yes (11/2)
#             :           :   :   housing = rent: no (1)
#             :           :   zip in {77004,77021}:
#             :           :   :...credit_history = critical: no (7)
#             :           :       credit_history = poor: yes (4/1)
#             :           :       credit_history = good:
#             :           :       :...phone = no: no (9)
#             :           :           phone = yes:
#             :           :           :...dependents <= 1: yes (7/1)
#             :           :               dependents > 1: no (2)
#             :           percent_of_income > 3:
#             :           :...housing = other: yes (5)
#             :               housing = rent:
#             :               :...other_credit = bank: no (1)
#             :               :   other_credit in {none,store}: yes (10/1)
#             :               housing = own:
#             :               :...status in {husband,wife}: yes (12/3)
#             :                   status = single:
#             :                   :...other_credit in {bank,store}: yes (4)
#             :                       other_credit = none:
#             :                       :...zip = 77004: yes (3/1)
#             :                           zip in {77021,77054}: no (7)
#             months_loan_duration <= 22:
#             :...status = wife: no (69/12)
#                 status in {husband,single}:
#                 :...credit_history = poor:
#                     :...existing_loans_count <= 1: yes (2)
#                     :   existing_loans_count > 1: no (7/1)
#                     credit_history = critical:
#                     :...other_credit in {none,store}: no (36/6)
#                     :   other_credit = bank:
#                     :   :...purpose in {business,car,car0,education,
#                     :       :           renovations}: yes (3)
#                     :       purpose = furniture/appliances: no (2)
#                     credit_history = good:
#                     :...savings_balance in {> 1000 USD,500 - 1000 USD,
#                         :                   unknown}: no (23/7)
#                         savings_balance = 100 - 500 USD: yes (8/2)
#                         savings_balance = < 100 USD:
#                         :...checking_balance = 1 - 200 USD:
#                             :...percent_of_income <= 1: yes (2)
#                             :   percent_of_income > 1: no (28/6)
#                             checking_balance = < 0 USD:
#                             :...purpose in {business,car,car0,education,
#                                 :           renovations}: yes (15/4)
#                                 purpose = furniture/appliances:
#                                 :...years_at_residence <= 1: no (5)
#                                     years_at_residence > 1:
#                                     :...months_loan_duration > 15: yes (10/1)
#                                         months_loan_duration <= 15:
#                                         :...housing = other: yes (1)
#                                             housing = own: no (4)
#                                             housing = rent:
#                                             :...amount <= 1193: no (2)
#                                                 amount > 1193: yes (2)
#
#
# Evaluation on training data (800 cases):
#
# 	    Decision Tree
# 	  ----------------
# 	  Size      Errors
#
# 	    51   63( 7.9%)   <<
#
#
# 	   (a)   (b)    <-classified as
# 	  ----  ----
# 	   530    25    (a): class no
# 	    38   207    (b): class yes
#
#
# 	Attribute usage:
#
# 	100.00%	zip
# 	 60.38%	checking_balance
# 	 54.50%	credit_history
# 	 47.00%	months_loan_duration
# 	 35.12%	status
# 	 32.12%	savings_balance
# 	 15.75%	other_credit
# 	 14.12%	percent_of_income
# 	  9.00%	housing
# 	  5.50%	purpose
# 	  3.75%	phone
# 	  3.50%	employment_duration
# 	  3.00%	years_at_residence
# 	  1.62%	job
# 	  1.12%	existing_loans_count
# 	  1.12%	dependents
# 	  0.50%	amount
#
#
# Time: 0.0 secs

# %% [markdown]
# ### Defining a model process
#
# How will you choose your analytical method? For example, predictive analytics, machine learning (supervised, unsupervised), neural networks or deep learning, etc.
#
# * How much transparency does this method allow your end users and yourself?
# * Are non-deterministic outcomes acceptable given your legal or ethical obligations around transparency and explainability?
# * Does your choice of analytical method allow you to sufficiently explain your results?
# * What particular tasks are associated with the type of analytical method you are using?
#
# We have selected a decision tree model due to the constraints listed in our introduction, and will be afforded full transparency into the model itself.
#
# ### Tools
#
# You have two options. The first: will you need to choose tools from available libraries?
#
# * How could results that look successful still contain bias?
# * Is there a trustworthy or audited source for the tools you need?
# * Have the tools you are using been associated with biased products?
# * Or, if you build from scratch: can you or a third-party test your tools for any features that can result in biased or unfair outcomes?
#
# We have chosen to use the `C5.0` package for decision trees, which is a trustworthy and industry-standard choice for this algorithm.

# %% [markdown]
# ## Step 4: Evaluate Model Performance
#
# Interesting. For our first decision tree experiment, it looks like `zip` was the most predictive feature - and it gave us an error rate of `7.9%`. Not bad for a first try; but remember the initial observation we had about zip code and race?
#
# Let's try attempting to improve our model's performance with a process called **adaptive boosting**.

# %%
# Apply decision tree to test data set.
credit_pred <- predict(credit_model, credit_test_new)

# Compare predicted class values to actuals
# prop.c = column percentages; prop.r = row percentages
CrossTable(credit_test_new$default, credit_pred,
             prop.chisq = FALSE, prop.c = FALSE, prop.r = FALSE,
             dnn = c('actual default', 'predicted default'))
# Out:
#
#    Cell Contents
# |-------------------------|
# |                       N |
# |         N / Table Total |
# |-------------------------|
#
#
# Total Observations in Table:  200
#
#
#                | predicted default
# actual default |        no |       yes | Row Total |
# ---------------|-----------|-----------|-----------|
#             no |       126 |        19 |       145 |
#                |     0.630 |     0.095 |           |
# ---------------|-----------|-----------|-----------|
#            yes |        20 |        35 |        55 |
#                |     0.100 |     0.175 |           |
# ---------------|-----------|-----------|-----------|
#   Column Total |       146 |        54 |       200 |
# ---------------|-----------|-----------|-----------|

# %% [markdown]
# ## Step 5: Improving Model Performance
#
# ** Adaptive Boosting** is a process in which many decision trees are built, and then the trees "vote" on the best class for each sample.
#
# When you combine many your weakly performing trees, you wind up with a team that is stronger than any one of the learners alone. This is a similar mentality to _two heads are better than one_, and _strength in numbers_. Let's try it:

# %%
credit_boost10 <- C5.0(credit_train_new[-16], 
                       credit_train_new$default, 
                       trials = 10)

# %%
summary(credit_boost10)
# Out:
# Call:
# C5.0.default(x = credit_train_new[-16], y = credit_train_new$default, trials
#  = 10)
#
#
# C5.0 [Release 2.07 GPL Edition]  	Fri May 25 06:52:16 2018
# -------------------------------
#
# Class specified by attribute `outcome'
#
# Read 800 cases (18 attributes) from undefined.data
#
# -----  Trial 0:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (317)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (47)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...credit_history in {perfect,very good}:
#         :...other_credit = none: yes (31/3)
#         :   other_credit in {bank,store}:
#         :   :...status = single: yes (7/1)
#         :       status = wife:
#         :       :...housing in {other,rent}: yes (2)
#         :       :   housing = own: no (7)
#         :       status = husband:
#         :       :...job = skilled: no (6/2)
#         :           job in {unemployed,unskilled}: yes (3)
#         :           job = management:
#         :           :...employment_duration in {< 1 year,1 - 4 years,
#         :               :                       4 - 7 years,
#         :               :                       unemployed}: no (2)
#         :               employment_duration = > 7 years: yes (2)
#         credit_history in {critical,good,poor}:
#         :...months_loan_duration > 22:
#             :...savings_balance = > 1000 USD: no (2/1)
#             :   savings_balance = 500 - 1000 USD: yes (3/1)
#             :   savings_balance = 100 - 500 USD:
#             :   :...employment_duration in {> 7 years,4 - 7 years,
#             :   :   :                       unemployed}: no (12/2)
#             :   :   employment_duration = 1 - 4 years: yes (5)
#             :   :   employment_duration = < 1 year:
#             :   :   :...status in {husband,single}: yes (6/1)
#             :   :       status = wife: no (1)
#             :   savings_balance = unknown:
#             :   :...checking_balance = 1 - 200 USD: no (14)
#             :   :   checking_balance = < 0 USD:
#             :   :   :...phone = no: yes (8/1)
#             :   :       phone = yes: no (4/1)
#             :   savings_balance = < 100 USD:
#             :   :...months_loan_duration > 47: yes (19/2)
#             :       months_loan_duration <= 47:
#             :       :...percent_of_income <= 3:
#             :           :...zip = 77054:
#             :           :   :...housing in {other,own}: yes (11/2)
#             :           :   :   housing = rent: no (1)
#             :           :   zip in {77004,77021}:
#             :           :   :...credit_history = critical: no (7)
#             :           :       credit_history = poor: yes (4/1)
#             :           :       credit_history = good:
#             :           :       :...phone = no: no (9)
#             :           :           phone = yes:
#             :           :           :...dependents <= 1: yes (7/1)
#             :           :               dependents > 1: no (2)
#             :           percent_of_income > 3:
#             :           :...housing = other: yes (5)
#             :               housing = rent:
#             :               :...other_credit = bank: no (1)
#             :               :   other_credit in {none,store}: yes (10/1)
#             :               housing = own:
#             :               :...status in {husband,wife}: yes (12/3)
#             :                   status = single:
#             :                   :...other_credit in {bank,store}: yes (4)
#             :                       other_credit = none:
#             :                       :...zip = 77004: yes (3/1)
#             :                           zip in {77021,77054}: no (7)
#             months_loan_duration <= 22:
#             :...status = wife: no (69/12)
#                 status in {husband,single}:
#                 :...credit_history = poor:
#                     :...existing_loans_count <= 1: yes (2)
#                     :   existing_loans_count > 1: no (7/1)
#                     credit_history = critical:
#                     :...other_credit in {none,store}: no (36/6)
#                     :   other_credit = bank:
#                     :   :...purpose in {business,car,car0,education,
#                     :       :           renovations}: yes (3)
#                     :       purpose = furniture/appliances: no (2)
#                     credit_history = good:
#                     :...savings_balance in {> 1000 USD,500 - 1000 USD,
#                         :                   unknown}: no (23/7)
#                         savings_balance = 100 - 500 USD: yes (8/2)
#                         savings_balance = < 100 USD:
#                         :...checking_balance = 1 - 200 USD:
#                             :...percent_of_income <= 1: yes (2)
#                             :   percent_of_income > 1: no (28/6)
#                             checking_balance = < 0 USD:
#                             :...purpose in {business,car,car0,education,
#                                 :           renovations}: yes (15/4)
#                                 purpose = furniture/appliances:
#                                 :...years_at_residence <= 1: no (5)
#                                     years_at_residence > 1:
#                                     :...months_loan_duration > 15: yes (10/1)
#                                         months_loan_duration <= 15:
#                                         :...housing = other: yes (1)
#                                             housing = own: no (4)
#                                             housing = rent:
#                                             :...amount <= 1193: no (2)
#                                                 amount > 1193: yes (2)
#
# -----  Trial 1:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (244.5)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (36.3)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...credit_history in {perfect,very good}: yes (63.7/24.7)
#         credit_history = poor:
#         :...percent_of_income <= 2: no (18.9/1.5)
#         :   percent_of_income > 2: yes (19.9/6.9)
#         credit_history = critical:
#         :...employment_duration in {4 - 7 years,unemployed}: no (21.6/2.3)
#         :   employment_duration in {< 1 year,> 7 years,1 - 4 years}:
#         :   :...savings_balance = > 1000 USD: yes (5.2/1.5)
#         :       savings_balance in {100 - 500 USD,500 - 1000 USD,
#         :       :                   unknown}: no (9.8/1.5)
#         :       savings_balance = < 100 USD:
#         :       :...dependents > 1: no (9.3/0.8)
#         :           dependents <= 1:
#         :           :...amount <= 1199: no (4.6)
#         :               amount > 1199: yes (47.1/12.9)
#         credit_history = good:
#         :...years_at_residence > 2:
#             :...amount > 6260:
#             :   :...amount <= 14896: yes (21.1/2.3)
#             :   :   amount > 14896: no (3.7)
#             :   amount <= 6260:
#             :   :...status = wife:
#             :       :...existing_loans_count <= 1: no (31.9/2.3)
#             :       :   existing_loans_count > 1: yes (5.2/1.5)
#             :       status = husband:
#             :       :...dependents > 1: no (2.3)
#             :       :   dependents <= 1:
#             :       :   :...zip in {77004,77054}: no (16.6/4.6)
#             :       :       zip = 77021: yes (9.3/0.8)
#             :       status = single:
#             :       :...amount > 1484: no (44.2/9.8)
#             :           amount <= 1484:
#             :           :...existing_loans_count <= 1: yes (23.4/4.6)
#             :               existing_loans_count > 1: no (2.3)
#             years_at_residence <= 2:
#             :...purpose = car0: yes (0)
#                 purpose in {business,education}: no (13.5/2.3)
#                 purpose in {car,furniture/appliances,renovations}:
#                 :...months_loan_duration <= 8: no (14.3/3.7)
#                     months_loan_duration > 8:
#                     :...employment_duration in {> 7 years,
#                         :                       unemployed}: yes (26.9/1.5)
#                         employment_duration in {< 1 year,1 - 4 years,
#                         :                       4 - 7 years}:
#                         :...other_credit = bank: yes (6/1.5)
#                             other_credit = store: no (1.5)
#                             other_credit = none:
#                             :...amount <= 1495: yes (42.3/5.4)
#                                 amount > 1495: [S1]
#
# SubTree [S1]
#
# savings_balance = 500 - 1000 USD: yes (0)
# savings_balance in {> 1000 USD,unknown}: no (6.2)
# savings_balance in {< 100 USD,100 - 500 USD}:
# :...months_loan_duration > 47: yes (9.1)
#     months_loan_duration <= 47:
#     :...months_loan_duration > 40: no (3.7)
#         months_loan_duration <= 40:
#         :...phone = no: no (25.1/9.8)
#             phone = yes: yes (10.6/1.5)
#
# -----  Trial 2:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (192.6)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (28.5)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...credit_history in {good,perfect}:
#         :...months_loan_duration <= 11:
#         :   :...amount <= 10875: no (36.8/5.3)
#         :   :   amount > 10875: yes (5.7)
#         :   months_loan_duration > 11:
#         :   :...savings_balance in {> 1000 USD,500 - 1000 USD}: no (18.8/5.1)
#         :       savings_balance in {< 100 USD,100 - 500 USD,unknown}:
#         :       :...other_credit = store: yes (5.3/1.2)
#         :           other_credit = bank:
#         :           :...credit_history = perfect: no (12.1/1.2)
#         :           :   credit_history = good:
#         :           :   :...years_at_residence <= 1: no (2.8)
#         :           :       years_at_residence > 1: yes (24.3/7)
#         :           other_credit = none:
#         :           :...percent_of_income <= 2:
#         :               :...purpose = business: yes (8.1/0.6)
#         :               :   purpose in {car0,education,
#         :               :   :           renovations}: no (5.3/1.2)
#         :               :   purpose = car:
#         :               :   :...amount <= 1386: yes (6.4)
#         :               :   :   amount > 1386:
#         :               :   :   :...dependents <= 1: no (26.7/4)
#         :               :   :       dependents > 1: yes (5.7/0.6)
#         :               :   purpose = furniture/appliances:
#         :               :   :...dependents > 1: no (3.4)
#         :               :       dependents <= 1:
#         :               :       :...existing_loans_count > 1: no (6.3/0.6)
#         :               :           existing_loans_count <= 1: [S1]
#         :               percent_of_income > 2:
#         :               :...percent_of_income <= 3: yes (26.9/4.3)
#         :                   percent_of_income > 3:
#         :                   :...savings_balance = 100 - 500 USD: yes (10.2/4.7)
#         :                       savings_balance = unknown:
#         :                       :...years_at_residence <= 1: no (3.4)
#         :                       :   years_at_residence > 1: yes (22.5/1.8)
#         :                       savings_balance = < 100 USD:
#         :                       :...purpose = business: no (4.1/1.2)
#         :                           purpose in {car0,education,
#         :                           :           renovations}: yes (14.8/3.5)
#         :                           purpose = car:
#         :                           :...housing in {other,rent}: yes (7.4)
#         :                           :   housing = own: no (18.4/6.9)
#         :                           purpose = furniture/appliances:
#         :                           :...housing = other: yes (5)
#         :                               housing in {own,rent}:
#         :                               :...dependents > 1: yes (4.1/0.6)
#         :                                   dependents <= 1:
#         :                                   :...amount <= 1882: no (15.3/1.2)
#         :                                       amount > 1882: yes (33/10.5)
#         credit_history in {critical,poor,very good}:
#         :...savings_balance in {100 - 500 USD,unknown}: no (47.3/5.8)
#             savings_balance in {< 100 USD,> 1000 USD,500 - 1000 USD}:
#             :...months_loan_duration > 28: yes (29/9)
#                 months_loan_duration <= 28:
#                 :...years_at_residence <= 1: no (13.4/1.2)
#                     years_at_residence > 1:
#                     :...amount > 5433: no (10.4)
#                         amount <= 5433:
#                         :...purpose in {education,renovations}: yes (7.6)
#                             purpose in {business,car,car0,furniture/appliances}:
#                             :...savings_balance = > 1000 USD: no (5.6)
#                                 savings_balance in {< 100 USD,500 - 1000 USD}:
#                                 :...years_at_residence <= 2: yes (20.7/7.4)
#                                     years_at_residence > 2:
#                                     :...amount > 3812: yes (6.5/0.6)
#                                         amount <= 3812:
#                                         :...existing_loans_count > 2: no (5.8)
#                                             existing_loans_count <= 2: [S2]
#
# SubTree [S1]
#
# employment_duration in {< 1 year,1 - 4 years,unemployed}: yes (33.7/7.6)
# employment_duration in {> 7 years,4 - 7 years}: no (5.8)
#
# SubTree [S2]
#
# purpose in {business,car,car0}: no (25.7/5.2)
# purpose = furniture/appliances:
# :...checking_balance = 1 - 200 USD: no (10.5)
#     checking_balance = < 0 USD:
#     :...savings_balance = < 100 USD: yes (19.2/5.8)
#         savings_balance = 500 - 1000 USD: no (5/0.6)
#
# -----  Trial 3:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (151.7)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (22.5)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...amount > 10722:
#         :...phone = no: no (2.8/0.5)
#         :   phone = yes:
#         :   :...savings_balance in {< 100 USD,> 1000 USD,100 - 500 USD,
#         :       :                   500 - 1000 USD}: yes (21.4/0.5)
#         :       savings_balance = unknown: no (10.2/4)
#         amount <= 10722:
#         :...status = wife:
#             :...purpose in {business,car0,education,furniture/appliances,
#             :   :           renovations}:
#             :   :...housing = other: no (8.6/2.4)
#             :   :   housing = own:
#             :   :   :...employment_duration in {< 1 year,> 7 years,1 - 4 years,
#             :   :   :   :                       4 - 7 years}: no (77.6/5.5)
#             :   :   :   employment_duration = unemployed: yes (6.8/2.2)
#             :   :   housing = rent:
#             :   :   :...existing_loans_count <= 1: no (18.4/3.2)
#             :   :       existing_loans_count > 1: yes (7.7/1.7)
#             :   purpose = car:
#             :   :...dependents > 1: no (7.3/0.5)
#             :       dependents <= 1:
#             :       :...zip = 77004: no (16.5/5)
#             :           zip in {77021,77054}:
#             :           :...other_credit = bank: no (3.4)
#             :               other_credit in {none,store}: yes (23/1)
#             status in {husband,single}:
#             :...other_credit = store: yes (17.8/3.7)
#                 other_credit in {bank,none}:
#                 :...job = management: no (48.5/12.5)
#                     job in {skilled,unemployed,unskilled}:
#                     :...credit_history = perfect: yes (15.7/7.4)
#                         credit_history = poor: no (18.4/3.6)
#                         credit_history = critical:
#                         :...other_credit = bank: yes (12.7/2.2)
#                         :   other_credit = none: no (60.3/17.3)
#                         credit_history = very good:
#                         :...purpose in {business,education}: no (9/1)
#                         :   purpose in {car,car0,furniture/appliances,
#                         :               renovations}: yes (19.6/1.7)
#                         credit_history = good:
#                         :...purpose in {business,education}: yes (17.7/5.4)
#                             purpose in {car0,renovations}: no (13.1/4)
#                             purpose = car:
#                             :...zip = 77004: no (18.2/3.2)
#                             :   zip in {77021,77054}:
#                             :   :...other_credit = bank: no (3.9)
#                             :       other_credit = none: [S1]
#                             purpose = furniture/appliances:
#                             :...months_loan_duration <= 8: no (8.3)
#                                 months_loan_duration > 8:
#                                 :...job = unemployed: yes (0)
#                                     job = unskilled: no (18.7/6.9)
#                                     job = skilled: [S2]
#
# SubTree [S1]
#
# employment_duration in {< 1 year,1 - 4 years,4 - 7 years}: yes (42.3/10.9)
# employment_duration in {> 7 years,unemployed}: no (13.3/2.8)
#
# SubTree [S2]
#
# savings_balance in {> 1000 USD,500 - 1000 USD}: no (3.9)
# savings_balance in {< 100 USD,100 - 500 USD,unknown}:
# :...other_credit = bank: yes (5.4)
#     other_credit = none:
#     :...employment_duration in {< 1 year,1 - 4 years,4 - 7 years,
#         :                       unemployed}: yes (64.6/16.3)
#         employment_duration = > 7 years: no (10.9/2.8)
#
# -----  Trial 4:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (121)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (17.9)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...months_loan_duration > 26:
#         :...job = unemployed: no (4.5)
#         :   job in {management,skilled,unskilled}:
#         :   :...dependents > 1: no (26.5/9.7)
#         :       dependents <= 1:
#         :       :...status = husband: yes (24.6/2.1)
#         :           status in {single,wife}:
#         :           :...months_loan_duration > 48: yes (11.1/0.4)
#         :               months_loan_duration <= 48:
#         :               :...savings_balance in {100 - 500 USD,
#         :                   :                   unknown}: no (27.2/10.8)
#         :                   savings_balance in {> 1000 USD,
#         :                   :                   500 - 1000 USD}: yes (3)
#         :                   savings_balance = < 100 USD:
#         :                   :...years_at_residence > 3: yes (25.7/3.8)
#         :                       years_at_residence <= 3:
#         :                       :...checking_balance = < 0 USD: [S1]
#         :                           checking_balance = 1 - 200 USD:
#         :                           :...years_at_residence <= 1: no (3.5/0.4)
#         :                               years_at_residence > 1: [S2]
#         months_loan_duration <= 26:
#         :...dependents > 1:
#             :...employment_duration in {< 1 year,> 7 years,
#             :   :                       unemployed}: yes (35.9/5.8)
#             :   employment_duration in {1 - 4 years,4 - 7 years}:
#             :   :...housing = other: yes (3.3)
#             :       housing in {own,rent}: no (23.8/1.9)
#             dependents <= 1:
#             :...years_at_residence > 3:
#                 :...months_loan_duration <= 7: yes (14.2/3.7)
#                 :   months_loan_duration > 7: no (150.8/39.9)
#                 years_at_residence <= 3:
#                 :...housing = other: yes (2.3/0.4)
#                     housing = rent:
#                     :...employment_duration in {< 1 year,> 7 years,
#                     :   :                       1 - 4 years}: yes (30.1/6)
#                     :   employment_duration in {4 - 7 years,
#                     :                           unemployed}: no (5.1)
#                     housing = own:
#                     :...job = unemployed: yes (8.5)
#                         job in {management,skilled,unskilled}:
#                         :...purpose in {business,education}: no (11.6)
#                             purpose in {car,car0,furniture/appliances,
#                             :           renovations}:
#                             :...years_at_residence <= 1:
#                                 :...credit_history in {critical,good,perfect,
#                                 :   :                  poor}: no (47.1/11)
#                                 :   credit_history = very good: yes (3.1)
#                                 years_at_residence > 1:
#                                 :...months_loan_duration <= 8: no (8.2)
#                                     months_loan_duration > 8:
#                                     :...months_loan_duration > 18:
#                                         :...amount <= 1484: yes (5.5)
#                                         :   amount > 1484: no (31.9/6.3)
#                                         months_loan_duration <= 18: [S3]
#
# SubTree [S1]
#
# credit_history = very good: no (0)
# credit_history = poor: yes (3.4)
# credit_history in {critical,good,perfect}:
# :...purpose in {car,renovations}: yes (6.3/1.8)
#     purpose in {business,car0,education,furniture/appliances}: no (19.6/0.4)
#
# SubTree [S2]
#
# credit_history in {critical,good,perfect,very good}: yes (20.5)
# credit_history = poor: no (3.4)
#
# SubTree [S3]
#
# months_loan_duration > 16: yes (25.7/3.1)
# months_loan_duration <= 16:
# :...months_loan_duration <= 13: yes (59.1/19.7)
#     months_loan_duration > 13: no (15.4/2.2)
#
# -----  Trial 5:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (96.6)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (14.3)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...months_loan_duration > 22:
#         :...savings_balance in {> 1000 USD,unknown}:
#         :   :...checking_balance = 1 - 200 USD: no (26.8/2.7)
#         :   :   checking_balance = < 0 USD:
#         :   :   :...dependents > 1: no (2.8)
#         :   :       dependents <= 1:
#         :   :       :...existing_loans_count > 1: no (2.5)
#         :   :           existing_loans_count <= 1:
#         :   :           :...employment_duration = < 1 year: no (2.6)
#         :   :               employment_duration in {> 7 years,1 - 4 years,
#         :   :                                       4 - 7 years,
#         :   :                                       unemployed}: yes (20.2/1.5)
#         :   savings_balance in {< 100 USD,100 - 500 USD,500 - 1000 USD}:
#         :   :...months_loan_duration > 47: yes (43.2/7)
#         :       months_loan_duration <= 47:
#         :       :...amount <= 2303: yes (52.2/8.7)
#         :           amount > 2303:
#         :           :...status = wife:
#         :               :...other_credit in {bank,store}: no (8.3)
#         :               :   other_credit = none:
#         :               :   :...months_loan_duration <= 28: no (14/1.7)
#         :               :       months_loan_duration > 28:
#         :               :       :...amount <= 2375: no (6.8)
#         :               :           amount > 2375: yes (19.8/3.3)
#         :               status in {husband,single}:
#         :               :...amount <= 2820: yes (15.8/0.3)
#         :                   amount > 2820:
#         :                   :...amount <= 3079: no (10.2)
#         :                       amount > 3079:
#         :                       :...other_credit in {bank,
#         :                           :                store}: yes (19.7/3.6)
#         :                           other_credit = none:
#         :                           :...housing = rent: yes (17.1/2.3)
#         :                               housing in {other,own}: [S1]
#         months_loan_duration <= 22:
#         :...employment_duration = 4 - 7 years: no (50.9/8.6)
#             employment_duration in {< 1 year,> 7 years,1 - 4 years,unemployed}:
#             :...housing = other:
#                 :...existing_loans_count > 2: no (3.2)
#                 :   existing_loans_count <= 2:
#                 :   :...other_credit = bank: no (6.3/1.4)
#                 :       other_credit in {none,store}: yes (21.9/5)
#                 housing = rent:
#                 :...savings_balance in {> 1000 USD,
#                 :   :                   100 - 500 USD}: yes (9.4/0.3)
#                 :   savings_balance = 500 - 1000 USD: no (2.2)
#                 :   savings_balance in {< 100 USD,unknown}:
#                 :   :...credit_history in {perfect,very good}: yes (3.7)
#                 :       credit_history = poor: no (2.7)
#                 :       credit_history in {critical,good}:
#                 :       :...job in {management,unemployed,
#                 :           :       unskilled}: no (20/4.4)
#                 :           job = skilled:
#                 :           :...dependents > 1: no (2.8)
#                 :               dependents <= 1: [S2]
#                 housing = own:
#                 :...savings_balance in {> 1000 USD,100 - 500 USD,
#                     :                   500 - 1000 USD}: no (32.1/6.3)
#                     savings_balance = unknown:
#                     :...years_at_residence <= 3: yes (22.7/5.4)
#                     :   years_at_residence > 3: no (7.6)
#                     savings_balance = < 100 USD:
#                     :...existing_loans_count > 1:
#                         :...years_at_residence > 3: no (12.9)
#                         :   years_at_residence <= 3:
#                         :   :...status = husband: yes (5.7)
#                         :       status in {single,wife}: no (22.7/4.7)
#                         existing_loans_count <= 1:
#                         :...job in {management,unemployed}: yes (7.1/0.3)
#                             job in {skilled,unskilled}:
#                             :...dependents > 1: yes (11.9/3.1)
#                                 dependents <= 1: [S3]
#
# SubTree [S1]
#
# employment_duration in {< 1 year,> 7 years,1 - 4 years,
# :                       unemployed}: no (41.6/13.1)
# employment_duration = 4 - 7 years: yes (11.3)
#
# SubTree [S2]
#
# purpose in {business,car,car0,furniture/appliances,renovations}: yes (39.6/9.9)
# purpose = education: no (2.6)
#
# SubTree [S3]
#
# employment_duration = > 7 years: no (8.2)
# employment_duration in {< 1 year,1 - 4 years,unemployed}:
# :...credit_history in {perfect,poor}: no (0)
#     credit_history in {critical,very good}: yes (5.8/1.1)
#     credit_history = good:
#     :...purpose in {business,car0}: no (1.7)
#         purpose in {car,education,renovations}: yes (26/9.3)
#         purpose = furniture/appliances:
#         :...years_at_residence <= 1: no (8.8)
#             years_at_residence > 1:
#             :...phone = no: no (29.9/10.3)
#                 phone = yes: yes (5.6/0.3)
#
# -----  Trial 6:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (76.5)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (11.3)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...credit_history in {perfect,very good}:
#         :...other_credit = none:
#         :   :...months_loan_duration <= 28: yes (29.4)
#         :   :   months_loan_duration > 28:
#         :   :   :...status in {husband,wife}: yes (10.9)
#         :   :       status = single: no (13.1/3.4)
#         :   other_credit in {bank,store}:
#         :   :...months_loan_duration <= 9: yes (7.3)
#         :       months_loan_duration > 9:
#         :       :...status = single: yes (7.6/2)
#         :           status = wife: no (10/1)
#         :           status = husband:
#         :           :...job in {management,skilled,unemployed}: no (18.2/4.5)
#         :               job = unskilled: yes (3.6)
#         credit_history in {critical,good,poor}:
#         :...amount > 10722:
#             :...housing in {other,own}: yes (22.5/1.4)
#             :   housing = rent: no (3.2)
#             amount <= 10722:
#             :...percent_of_income <= 1:
#                 :...credit_history = poor: no (9.4)
#                 :   credit_history in {critical,good}:
#                 :   :...job = management: yes (7.6/3)
#                 :       job in {unemployed,unskilled}: no (17.4/1.1)
#                 :       job = skilled:
#                 :       :...other_credit = store: no (0)
#                 :           other_credit = bank: yes (3.6)
#                 :           other_credit = none:
#                 :           :...years_at_residence <= 2: yes (17.1/6.1)
#                 :               years_at_residence > 2: no (24/2.3)
#                 percent_of_income > 1:
#                 :...months_loan_duration <= 11: no (50.2/10.6)
#                     months_loan_duration > 11:
#                     :...checking_balance = 1 - 200 USD:
#                         :...savings_balance in {> 1000 USD,
#                         :   :                   500 - 1000 USD}: yes (13/3.1)
#                         :   savings_balance = unknown: no (30.8/7.9)
#                         :   savings_balance = 100 - 500 USD:
#                         :   :...existing_loans_count > 3: yes (2)
#                         :   :   existing_loans_count <= 3:
#                         :   :   :...months_loan_duration <= 27: no (24.6/5.1)
#                         :   :       months_loan_duration > 27: yes (12.8/3.2)
#                         :   savings_balance = < 100 USD:
#                         :   :...years_at_residence <= 1: no (19.4/4.1)
#                         :       years_at_residence > 1:
#                         :       :...housing = rent: no (14/1.2)
#                         :           housing in {other,own}:
#                         :           :...months_loan_duration > 28: yes (17.7)
#                         :               months_loan_duration <= 28:
#                         :               :...status = wife: no (10.5)
#                         :                   status in {husband,single}: [S1]
#                         checking_balance = < 0 USD:
#                         :...job = management:
#                             :...savings_balance = 500 - 1000 USD: no (0)
#                             :   savings_balance = unknown: yes (3.8)
#                             :   savings_balance in {< 100 USD,> 1000 USD,
#                             :   :                   100 - 500 USD}:
#                             :   :...amount <= 7596: no (23.4/1.4)
#                             :       amount > 7596: yes (4.4/1)
#                             job in {skilled,unemployed,unskilled}:
#                             :...amount > 5743: yes (15.5)
#                                 amount <= 5743: [S2]
#
# SubTree [S1]
#
# other_credit in {bank,store}: yes (7.9/0.2)
# other_credit = none:
# :...employment_duration = unemployed: no (6.8)
#     employment_duration in {< 1 year,> 7 years,1 - 4 years,4 - 7 years}:
#     :...existing_loans_count > 1: no (14/5.8)
#         existing_loans_count <= 1:
#         :...status = husband: no (10.3/3.1)
#             status = single: yes (19.4/4.3)
#
# SubTree [S2]
#
# savings_balance in {> 1000 USD,500 - 1000 USD,unknown}: no (22.6/9)
# savings_balance = 100 - 500 USD: yes (10.7/1)
# savings_balance = < 100 USD:
# :...purpose in {business,car0,education}: yes (8.2)
#     purpose in {car,furniture/appliances,renovations}:
#     :...housing = other: yes (10.2/1)
#         housing in {own,rent}:
#         :...other_credit = bank: yes (12.2/2)
#             other_credit = store: no (4.3/1.2)
#             other_credit = none:
#             :...amount <= 1913:
#                 :...employment_duration in {< 1 year,> 7 years,
#                 :   :                       1 - 4 years}: no (60.2/14.4)
#                 :   employment_duration in {4 - 7 years,
#                 :                           unemployed}: yes (10.6/1.2)
#                 amount > 1913:
#                 :...months_loan_duration > 39: no (4.2)
#                     months_loan_duration <= 39:
#                     :...employment_duration in {< 1 year,> 7 years,4 - 7 years,
#                         :                       unemployed}: yes (30.4/4.1)
#                         employment_duration = 1 - 4 years:
#                         :...zip = 77054: yes (9.4)
#                             zip in {77004,77021}:
#                             :...months_loan_duration <= 21: yes (13.4/3)
#                                 months_loan_duration > 21: no (10.2/0.2)
#
# -----  Trial 7:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (60.5)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (9)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...status = wife:
#         :...months_loan_duration > 42: yes (12.2)
#         :   months_loan_duration <= 42:
#         :   :...other_credit in {bank,store}: no (35.5/3.7)
#         :       other_credit = none:
#         :       :...savings_balance in {> 1000 USD,100 - 500 USD,
#         :           :                   500 - 1000 USD}: no (28.8/3.6)
#         :           savings_balance = unknown: yes (16.4/5.3)
#         :           savings_balance = < 100 USD:
#         :           :...percent_of_income <= 2:
#         :               :...amount <= 1313: yes (4.7/0.8)
#         :               :   amount > 1313: no (29.7/3.4)
#         :               percent_of_income > 2:
#         :               :...purpose in {business,
#         :                   :           furniture/appliances}: no (23.3/8.2)
#         :                   purpose in {car,car0,education,
#         :                               renovations}: yes (31/3.9)
#         status in {husband,single}:
#         :...other_credit = store: yes (23.9/3.1)
#             other_credit in {bank,none}:
#             :...credit_history = perfect:
#                 :...other_credit = bank: no (6.2/1.6)
#                 :   other_credit = none: yes (20.7/2.6)
#                 credit_history = poor:
#                 :...savings_balance in {> 1000 USD,100 - 500 USD,
#                 :   :                   500 - 1000 USD,unknown}: no (13.8)
#                 :   savings_balance = < 100 USD:
#                 :   :...employment_duration in {< 1 year,> 7 years,4 - 7 years,
#                 :       :                       unemployed}: yes (14.9)
#                 :       employment_duration = 1 - 4 years: no (6.8)
#                 credit_history = very good:
#                 :...months_loan_duration > 42: no (5)
#                 :   months_loan_duration <= 42:
#                 :   :...amount <= 454: no (3.9)
#                 :       amount > 454: yes (27.8/4.7)
#                 credit_history = critical:
#                 :...other_credit = bank: yes (12.1/2.4)
#                 :   other_credit = none:
#                 :   :...existing_loans_count > 2: no (9.3)
#                 :       existing_loans_count <= 2:
#                 :       :...purpose = car0: no (0)
#                 :           purpose in {business,education}: yes (10/0.6)
#                 :           purpose in {car,furniture/appliances,renovations}:
#                 :           :...dependents > 1: no (11.5)
#                 :               dependents <= 1:
#                 :               :...percent_of_income <= 2: yes (10.8/0.7)
#                 :                   percent_of_income > 2:
#                 :                   :...phone = yes: no (15.9)
#                 :                       phone = no:
#                 :                       :...zip in {77004,77021}: yes (15.2/3.8)
#                 :                           zip = 77054: no (10.8/1.5)
#                 credit_history = good:
#                 :...housing = rent:
#                     :...zip = 77021: yes (29.1/1.7)
#                     :   zip in {77004,77054}:
#                     :   :...years_at_residence <= 1: no (3.8)
#                     :       years_at_residence > 1:
#                     :       :...dependents > 1: no (2.3)
#                     :           dependents <= 1:
#                     :           :...percent_of_income <= 2: no (8.3/3.1)
#                     :               percent_of_income > 2:
#                     :               :...amount <= 1207: no (5.6/1.6)
#                     :                   amount > 1207: yes (29.1/3.5)
#                     housing in {other,own}:
#                     :...savings_balance in {> 1000 USD,
#                         :                   100 - 500 USD}: yes (20/6.7)
#                         savings_balance = 500 - 1000 USD: no (3.6)
#                         savings_balance = unknown:
#                         :...employment_duration = < 1 year: no (7.2)
#                         :   employment_duration in {> 7 years,1 - 4 years,
#                         :   :                       4 - 7 years,unemployed}:
#                         :   :...existing_loans_count > 1: no (2.5)
#                         :       existing_loans_count <= 1:
#                         :       :...job in {management,skilled,
#                         :           :       unemployed}: yes (41/11.5)
#                         :           job = unskilled: no (5.3)
#                         savings_balance = < 100 USD:
#                         :...years_at_residence <= 1:
#                             :...amount <= 11328: no (25.2/3.7)
#                             :   amount > 11328: yes (2.4)
#                             years_at_residence > 1:
#                             :...years_at_residence > 3: [S1]
#                                 years_at_residence <= 3:
#                                 :...other_credit = bank: yes (8.9/0.7)
#                                     other_credit = none:
#                                     :...years_at_residence <= 2: yes (49.1/13.2)
#                                         years_at_residence > 2:
#                                         :...months_loan_duration > 24: no (9.5)
#                                             months_loan_duration <= 24: [S2]
#
# SubTree [S1]
#
# employment_duration = < 1 year: yes (7)
# employment_duration in {> 7 years,1 - 4 years,4 - 7 years,unemployed}:
# :...months_loan_duration > 40: yes (4)
#     months_loan_duration <= 40:
#     :...amount <= 7582: no (32.4/2.5)
#         amount > 7582: yes (2)
#
# SubTree [S2]
#
# months_loan_duration <= 16: no (17.9/6.3)
# months_loan_duration > 16: yes (14.2)
#
# -----  Trial 8:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (47.6)
# zip in {77004,77021,77054}:
# :...checking_balance in {> 200 USD,unknown}: yes (7.1)
#     checking_balance in {< 0 USD,1 - 200 USD}:
#     :...credit_history = perfect: yes (41.3/9.1)
#         credit_history = critical:
#         :...employment_duration = 4 - 7 years: no (30/1.2)
#         :   employment_duration in {< 1 year,> 7 years,1 - 4 years,unemployed}:
#         :   :...purpose in {business,education}: yes (11.3/3.1)
#         :       purpose in {car,car0,renovations}: no (48.8/12.9)
#         :       purpose = furniture/appliances:
#         :       :...employment_duration in {> 7 years,unemployed}: no (16.3/1.4)
#         :           employment_duration in {< 1 year,1 - 4 years}:
#         :           :...amount <= 1175: no (5.2)
#         :               amount > 1175: yes (26.3/4.8)
#         credit_history in {good,poor,very good}:
#         :...checking_balance = < 0 USD:
#             :...existing_loans_count > 1: yes (29.9/2.7)
#             :   existing_loans_count <= 1:
#             :   :...amount <= 1372:
#             :       :...months_loan_duration > 16: yes (30.8)
#             :       :   months_loan_duration <= 16:
#             :       :   :...employment_duration in {< 1 year,1 - 4 years,
#             :       :       :                       4 - 7 years,
#             :       :       :                       unemployed}: yes (50.6/9.7)
#             :       :       employment_duration = > 7 years: no (8.4/0.7)
#             :       amount > 1372:
#             :       :...purpose in {business,renovations}: yes (3.9)
#             :           purpose in {car0,education}: no (5.3/0.2)
#             :           purpose = car:
#             :           :...years_at_residence <= 2: yes (16.2/2.2)
#             :           :   years_at_residence > 2:
#             :           :   :...amount <= 4796: no (32.1/1.3)
#             :           :       amount > 4796: yes (9.7/2.2)
#             :           purpose = furniture/appliances:
#             :           :...months_loan_duration <= 22:
#             :               :...amount > 3878: yes (3.3)
#             :               :   amount <= 3878:
#             :               :   :...job in {management,skilled,
#             :               :       :       unskilled}: no (42/5.1)
#             :               :       job = unemployed: yes (2.7)
#             :               months_loan_duration > 22:
#             :               :...percent_of_income <= 1: no (10.6/1.5)
#             :                   percent_of_income > 1:
#             :                   :...dependents > 1: yes (7.9)
#             :                       dependents <= 1: [S1]
#             checking_balance = 1 - 200 USD:
#             :...amount > 9857: yes (18.9/3.2)
#                 amount <= 9857:
#                 :...housing = rent:
#                     :...employment_duration in {4 - 7 years,
#                     :   :                       unemployed}: no (11.7)
#                     :   employment_duration in {< 1 year,> 7 years,1 - 4 years}:
#                     :   :...credit_history = poor: no (3)
#                     :       credit_history in {good,very good}:
#                     :       :...job = management: no (7.7/1.5)
#                     :           job in {skilled,unemployed,
#                     :                   unskilled}: yes (31.9/2.6)
#                     housing in {other,own}:
#                     :...savings_balance in {> 1000 USD,100 - 500 USD,
#                         :                   500 - 1000 USD,
#                         :                   unknown}: no (96.4/19)
#                         savings_balance = < 100 USD:
#                         :...housing = other: yes (7.5/0.5)
#                             housing = own:
#                             :...existing_loans_count > 1: no (11/1.1)
#                                 existing_loans_count <= 1:
#                                 :...months_loan_duration <= 8: no (14.8/3.1)
#                                     months_loan_duration > 8:
#                                     :...years_at_residence <= 1: no (16.2/3.6)
#                                         years_at_residence > 1:
#                                         :...amount > 5998: no (6.9)
#                                             amount <= 5998: [S2]
#
# SubTree [S1]
#
# employment_duration in {< 1 year,4 - 7 years}: yes (21/1.3)
# employment_duration in {> 7 years,1 - 4 years,unemployed}: no (24.4/8.5)
#
# SubTree [S2]
#
# years_at_residence <= 3: yes (27.5/4.2)
# years_at_residence > 3: no (13.7/3.5)
#
# -----  Trial 9:  -----
#
# Decision tree:
#
# zip in {77005,77030}: no (37.6)
# zip in {77004,77021,77054}:
# :...savings_balance = > 1000 USD:
#     :...purpose in {business,car,car0,furniture/appliances}: no (17.5/2.3)
#     :   purpose in {education,renovations}: yes (9.5)
#     savings_balance = 500 - 1000 USD:
#     :...zip in {77004,77021}: no (15.6/0.4)
#     :   zip = 77054: yes (7/1)
#     savings_balance = 100 - 500 USD:
#     :...employment_duration in {> 7 years,4 - 7 years}:
#     :   :...months_loan_duration <= 42: no (26.1/3.5)
#     :   :   months_loan_duration > 42: yes (7.7/2.1)
#     :   employment_duration in {< 1 year,1 - 4 years,unemployed}:
#     :   :...other_credit in {bank,store}: yes (11.8)
#     :       other_credit = none:
#     :       :...credit_history in {critical,poor}: no (6.1/0.1)
#     :           credit_history in {good,perfect,very good}:
#     :           :...purpose in {business,car,car0,education,
#     :               :           furniture/appliances}: yes (32.2/3.7)
#     :               purpose = renovations: no (3.2)
#     savings_balance = unknown:
#     :...purpose in {business,education,renovations}: no (22.7)
#     :   purpose in {car,car0,furniture/appliances}:
#     :   :...months_loan_duration > 45: no (6.8)
#     :       months_loan_duration <= 45:
#     :       :...credit_history in {critical,poor}: no (7/0.4)
#     :           credit_history in {perfect,very good}: yes (3.5/0.4)
#     :           credit_history = good:
#     :           :...job = unskilled: no (7.1)
#     :               job in {management,skilled,unemployed}:
#     :               :...employment_duration = 1 - 4 years: yes (23.1/2.1)
#     :                   employment_duration in {< 1 year,> 7 years,4 - 7 years,
#     :                   :                       unemployed}:
#     :                   :...status = wife: yes (9.6/2)
#     :                       status in {husband,single}:
#     :                       :...months_loan_duration <= 33: no (38.2/13.3)
#     :                           months_loan_duration > 33: yes (3)
#     savings_balance = < 100 USD:
#     :...months_loan_duration > 15:
#         :...months_loan_duration > 47: yes (27.1/3.8)
#         :   months_loan_duration <= 47:
#         :   :...percent_of_income > 3:
#         :       :...credit_history in {perfect,poor,very good}: yes (23.4)
#         :       :   credit_history in {critical,good}:
#         :       :   :...housing in {other,rent}: yes (39.2/7.8)
#         :       :       housing = own:
#         :       :       :...other_credit = bank: yes (5)
#         :       :           other_credit in {none,store}:
#         :       :           :...months_loan_duration > 28: yes (17/3.1)
#         :       :               months_loan_duration <= 28: [S1]
#         :       percent_of_income <= 3:
#         :       :...zip = 77054:
#         :           :...job in {management,unemployed}: no (8/1.1)
#         :           :   job in {skilled,unskilled}: yes (36.1/5.8)
#         :           zip in {77004,77021}:
#         :           :...amount <= 2333: yes (17.1/0.6)
#         :               amount > 2333:
#         :               :...other_credit = store: yes (4.6/0.5)
#         :                   other_credit in {bank,none}:
#         :                   :...credit_history = critical: no (17.5/0.1)
#         :                       credit_history in {good,perfect,poor,very good}:
#         :                       :...months_loan_duration > 28: no (22.9/2.8)
#         :                           months_loan_duration <= 28:
#         :                           :...housing = other: yes (4.3)
#         :                               housing in {own,rent}:
#         :                               :...status = wife: no (5.9/0.1)
#         :                                   status in {husband,single}: [S2]
#         months_loan_duration <= 15:
#         :...credit_history in {perfect,very good}: yes (15.9/3.8)
#             credit_history in {critical,good,poor}:
#             :...purpose in {business,car0,renovations}: no (5.5/1.1)
#                 purpose = education: yes (4.8/0.4)
#                 purpose = furniture/appliances:
#                 :...status = wife: no (22.9)
#                 :   status in {husband,single}:
#                 :   :...percent_of_income <= 1: yes (4.3)
#                 :       percent_of_income > 1:
#                 :       :...years_at_residence <= 1: no (10.4)
#                 :           years_at_residence > 1:
#                 :           :...months_loan_duration <= 8: no (8.7)
#                 :               months_loan_duration > 8:
#                 :               :...amount <= 717: no (8.5)
#                 :                   amount > 717: yes (32.8/13.3)
#                 purpose = car:
#                 :...years_at_residence <= 1: yes (8.3)
#                     years_at_residence > 1:
#                     :...dependents > 1: no (9.5)
#                         dependents <= 1:
#                         :...credit_history = poor: yes (4.8)
#                             credit_history in {critical,good}:
#                             :...housing = other: no (7.1)
#                                 housing in {own,rent}:
#                                 :...other_credit = store: no (0)
#                                     other_credit = bank: yes (2.4)
#                                     other_credit = none: [S3]
#
# SubTree [S1]
#
# employment_duration in {< 1 year,> 7 years,1 - 4 years,
# :                       4 - 7 years}: no (42/10.2)
# employment_duration = unemployed: yes (7.4/0.5)
#
# SubTree [S2]
#
# other_credit = bank: no (18.3/5.4)
# other_credit = none: yes (20/7.1)
#
# SubTree [S3]
#
# checking_balance in {> 200 USD,1 - 200 USD,unknown}: no (7.2)
# checking_balance = < 0 USD:
# :...years_at_residence <= 2: yes (9.2)
#     years_at_residence > 2:
#     :...amount > 3676: yes (3.2)
#         amount <= 3676:
#         :...zip in {77004,77054}: no (12.9)
#             zip = 77021: yes (10.2/3.8)
#
#
# Evaluation on training data (800 cases):
#
# Trial	    Decision Tree
# -----	  ----------------
# 	  Size      Errors
#
#    0	    51   63( 7.9%)
#    1	    32  105(13.1%)
#    2	    43  109(13.6%)
#    3	    34  106(13.2%)
#    4	    33  113(14.1%)
#    5	    46   80(10.0%)
#    6	    50   78( 9.8%)
#    7	    50   83(10.4%)
#    8	    38   83(10.4%)
#    9	    56   82(10.2%)
# boost	          0( 0.0%)   <<
#
#
# 	   (a)   (b)    <-classified as
# 	  ----  ----
# 	   555          (a): class no
# 	         245    (b): class yes
#
#
# 	Attribute usage:
#
# 	100.00%	zip
# 	 60.38%	checking_balance
# 	 60.38%	savings_balance
# 	 59.00%	months_loan_duration
# 	 58.50%	credit_history
# 	 56.00%	amount
# 	 55.88%	other_credit
# 	 55.75%	status
# 	 54.25%	percent_of_income
# 	 54.25%	dependents
# 	 54.12%	purpose
# 	 52.75%	housing
# 	 52.25%	job
# 	 52.00%	employment_duration
# 	 50.75%	years_at_residence
# 	 44.88%	existing_loans_count
# 	 15.12%	phone
#
#
# Time: 0.1 secs

# %% [markdown]
# ## Step 6: Spotting Potential Bias
#
# Reflect again on when we removed obviously biased columns in our original data set (`race`, `gender`, and `age`).
#
# Using these features to discriminate on services is prohibited by law, and examples of each being used in machine learning models are plentiful: race being associated with predictions of recidivism [5]; gender affecting displayed job-related ads [18]; race affecting displayed search ads [57]; Boston’s Street Bump app focusing pothole repair on affluent neighborhoods [53]; Amazon’s same day delivery being unavailable in black neighborhoods [34]; and Facebook showing either “white” or “black” movie trailers based upon “ethnic affiliation” [56]. For more, please check [1]().
#
# How can we tell if any of the features used by our model are unintentionally discriminating by gender, age, or race?
#
# First, let's take a look at race and default status:

# %%
preds <- data.frame(credit_pred, credit_test$race, credit_test$gender, credit_test$age)
colnames(preds) <- c("credit_pred", "race", "gender", "age")

ggplot(preds, aes(credit_pred)) + geom_bar(aes(fill = race))

# %%
table(preds$credit_pred, preds$race)
# Out:
#
#       AA AS CA MR
#   no  32 19 89  6
#   yes 32  7 10  5

# %% [markdown]
# Uh oh. That doesn't look good at all - it appears that the majority of predictions of `yes` for loan defaults are for African Americans - disproportionately many, given that the likelihood of an applicant to default is `30%` for the full data set. Having a `50%` probability of default for `AA` is a sure flag that something has gone wrong.
#
# Gut feel is not as convincing as numbers, however: so precisely how unlikely is it that we would see half defaults from a particular race when we should have a proportion closer to thirty percent?

# %%
# Probabilities for our predictions, by race.

1 - pbinom(32, 64, 0.3)      # African American
1 - pbinom(7, 26, 0.3)    # Asian American
1 - pbinom(10, 99, 0.3)     # Caucasian
1 - pbinom(5, 11, 0.3)    # Hispanic or Mixed Race
# Out:
# [1] 0.0002504319
# [1] 0.5395095
# [1] 0.999998
# [1] 0.07822479

# %% [markdown]
# What could have gone wrong? Let's try running our models again, removing zip code.

# %%
zip_bias <- c('zip')

credit_train_sans_zip <- credit_train_new[ , !(names(credit_train_new) %in% zip_bias)]
credit_test_sans_zip <- credit_test_new[, !(names(credit_test_new) %in% zip_bias)]

# %%
credit_model_sans_zip <- C5.0(credit_train_sans_zip[-16], 
                     credit_train_sans_zip$default)

credit_model_sans_zip
# Out:
# Call:
# C5.0.default(x = credit_train_sans_zip[-16], y = credit_train_sans_zip$default)
#
# Classification Tree
# Number of samples: 800
# Number of predictors: 16
#
# Tree size: 58
#
# Non-standard options: attempt to group attributes

# %%
summary(credit_model_sans_zip)
# Out:
# Call:
# C5.0.default(x = credit_train_sans_zip[-16], y = credit_train_sans_zip$default)
#
#
# C5.0 [Release 2.07 GPL Edition]  	Fri May 25 06:54:16 2018
# -------------------------------
#
# Class specified by attribute `outcome'
#
# Read 800 cases (17 attributes) from undefined.data
#
# Decision tree:
#
# checking_balance = unknown: no (307/34)
# checking_balance in {< 0 USD,> 200 USD,1 - 200 USD}:
# :...credit_history in {perfect,very good}:
#     :...other_credit = none: yes (35/5)
#     :   other_credit in {bank,store}:
#     :   :...status = single: yes (7/1)
#     :       status = wife:
#     :       :...housing in {other,rent}: yes (2)
#     :       :   housing = own: no (7)
#     :       status = husband:
#     :       :...employment_duration in {< 1 year,1 - 4 years}: no (7/2)
#     :           employment_duration in {> 7 years,unemployed}: yes (3)
#     :           employment_duration = 4 - 7 years:
#     :           :...months_loan_duration <= 21: no (2)
#     :               months_loan_duration > 21: yes (2)
#     credit_history in {critical,good,poor}:
#     :...months_loan_duration <= 11: no (76/11)
#         months_loan_duration > 11:
#         :...checking_balance = > 200 USD:
#             :...dependents <= 1: no (33/7)
#             :   dependents > 1: yes (3)
#             checking_balance = 1 - 200 USD:
#             :...months_loan_duration > 28:
#             :   :...savings_balance = 500 - 1000 USD: yes (0)
#             :   :   savings_balance = unknown: no (9)
#             :   :   savings_balance in {< 100 USD,> 1000 USD,100 - 500 USD}:
#             :   :   :...status = husband: yes (7)
#             :   :       status = single:
#             :   :       :...percent_of_income > 3: yes (8)
#             :   :       :   percent_of_income <= 3:
#             :   :       :   :...purpose in {business,car,car0,education,
#             :   :       :       :           renovations}: no (3)
#             :   :       :       purpose = furniture/appliances: yes (3)
#             :   :       status = wife:
#             :   :       :...housing = other: yes (3)
#             :   :           housing = rent: no (3)
#             :   :           housing = own:
#             :   :           :...purpose = business: no (3)
#             :   :               purpose in {car,car0,education,
#             :   :                           furniture/appliances,
#             :   :                           renovations}: yes (7/1)
#             :   months_loan_duration <= 28:
#             :   :...status = wife: no (37/6)
#             :       status in {husband,single}:
#             :       :...employment_duration in {4 - 7 years,
#             :           :                       unemployed}: no (22/2)
#             :           employment_duration in {< 1 year,> 7 years,1 - 4 years}:
#             :           :...dependents > 1:
#             :               :...job in {management,skilled,
#             :               :   :       unemployed}: yes (4)
#             :               :   job = unskilled: no (1)
#             :               dependents <= 1:
#             :               :...housing = other: no (2)
#             :                   housing = rent:
#             :                   :...credit_history in {critical,
#             :                   :   :                  poor}: no (3)
#             :                   :   credit_history = good: yes (9/1)
#             :                   housing = own:
#             :                   :...job = management: yes (2)
#             :                       job in {skilled,unemployed}: no (22/7)
#             :                       job = unskilled:
#             :                       :...amount <= 1829: no (5/1)
#             :                           amount > 1829: yes (4)
#             checking_balance = < 0 USD:
#             :...job = management: no (22/5)
#                 job in {skilled,unemployed,unskilled}:
#                 :...savings_balance in {> 1000 USD,
#                     :                   500 - 1000 USD}: no (4)
#                     savings_balance in {< 100 USD,100 - 500 USD,unknown}:
#                     :...percent_of_income <= 2:
#                         :...other_credit = bank: yes (4)
#                         :   other_credit = store: no (1)
#                         :   other_credit = none:
#                         :   :...housing in {other,rent}: no (13/2)
#                         :       housing = own:
#                         :       :...months_loan_duration <= 16: no (7/1)
#                         :           months_loan_duration > 16: yes (19/6)
#                         percent_of_income > 2:
#                         :...amount > 5595: yes (11)
#                             amount <= 5595:
#                             :...credit_history = critical:
#                                 :...percent_of_income > 3: no (9/1)
#                                 :   percent_of_income <= 3:
#                                 :   :...months_loan_duration > 24: no (2)
#                                 :       months_loan_duration <= 24:
#                                 :       :...job in {skilled,
#                                 :           :       unemployed}: yes (3)
#                                 :           job = unskilled: no (1)
#                                 credit_history in {good,poor}:
#                                 :...existing_loans_count > 1:
#                                     :...job in {skilled,unemployed}: yes (7)
#                                     :   job = unskilled: no (1)
#                                     existing_loans_count <= 1:
#                                     :...other_credit = store: no (2/1)
#                                         other_credit = bank:
#                                         :...years_at_residence <= 3: yes (2)
#                                         :   years_at_residence > 3: no (4)
#                                         other_credit = none: [S1]
#
# SubTree [S1]
#
# purpose in {business,car0,education,renovations}: yes (3)
# purpose = car:
# :...years_at_residence <= 2: yes (9)
# :   years_at_residence > 2:
# :   :...housing in {other,rent}: yes (5)
# :       housing = own: no (4)
# purpose = furniture/appliances:
# :...savings_balance = 100 - 500 USD: yes (4)
#     savings_balance = unknown: no (2/1)
#     savings_balance = < 100 USD:
#     :...months_loan_duration <= 16: no (4)
#         months_loan_duration > 16: yes (16/4)
#
#
# Evaluation on training data (800 cases):
#
# 	    Decision Tree
# 	  ----------------
# 	  Size      Errors
#
# 	    57   99(12.4%)   <<
#
#
# 	   (a)   (b)    <-classified as
# 	  ----  ----
# 	   537    18    (a): class no
# 	    81   164    (b): class yes
#
#
# 	Attribute usage:
#
# 	100.00%	checking_balance
# 	 61.62%	credit_history
# 	 54.00%	months_loan_duration
# 	 24.62%	job
# 	 22.88%	savings_balance
# 	 22.25%	status
# 	 20.50%	other_credit
# 	 18.38%	percent_of_income
# 	 15.00%	housing
# 	 12.25%	amount
# 	 11.00%	employment_duration
# 	 11.00%	dependents
# 	  7.88%	purpose
# 	  7.88%	existing_loans_count
# 	  3.00%	years_at_residence
#
#
# Time: 0.0 secs

# %%
credit_pred_sans_zip <- predict(credit_model_sans_zip, credit_test_sans_zip)

# %% [markdown]
# That looks quite a bit better, but still higher than the percentage of defaults for African Americans in the full data set. Lets take a look to see if our values have improved:

# %%
preds_sans_zip <- data.frame(credit_pred_sans_zip, credit_test$race, credit_test$gender, credit_test$age)
colnames(preds_sans_zip) <- c("credit_pred", "race", "gender", "age")

ggplot(preds_sans_zip, aes(credit_pred_sans_zip)) + geom_bar(aes(fill = race))

# %%
table(preds_sans_zip$credit_pred, preds_sans_zip$race)
# Out:
#
#       AA AS CA MR
#   no  45 18 95  8
#   yes 19  8  4  3

# %% [markdown]
# Percentages for defaults by marginalized groups are now closer to percentages for the full sample, but there is still some work to be done.

# %%
# Probabilities for our predictions, by race.

1 - dbinom(19, 64, 0.3)      # African American
1 - dbinom(8, 26, 0.3)    # Asian American
1 - dbinom(4, 99, 0.3)     # Caucasian
1 - dbinom(3, 11, 0.3)    # Hispanic or Mixed Race
# Out:
# [1] 0.8915509
# [1] 0.8330862
# [1] 1
# [1] 0.7431781

# %% [markdown]
# Let's check to see if there are any other correlations between variables. What about gender, for instance?

# %%
ggplot(preds_sans_zip, aes(credit_pred)) + geom_bar(aes(fill = gender))

# %% [markdown]
# Looks like we're good there. What about age?

# %%
preds2 <- data.frame(preds_sans_zip, cut(preds_sans_zip$age, seq(min(preds_sans_zip$age), max(preds_sans_zip$age), 10)))
colnames(preds2) <- c("credit_pred", "race", "gender", "age", "age_breaks")

ggplot(preds2, aes(credit_pred)) + geom_bar(aes(fill = age_breaks))

# %% [markdown]
# Also looks like we're okay there. But what about columns that might be tied to age, or to gender? If you run a chisquare test, you will find that `gender` and `status` are inextricably linked:

# %% [markdown]
# ## Sources
#
# 1. _Proxy Discrimination in Data-Driven Systems_
#
# 2.  David Maxwell Chickering and David Heckerman. _A decision theoretic approach to targeted advertising_. In Proceedings of the Sixteenth Conference on Uncertainty in Artificial Intelligence, UAI’00, pages 82–88, San Francisco, CA, USA, 2000. Morgan Kaufmann Publishers Inc.
#
# 3.
#
# 4.
#
# 5.
#
# 6.
